# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
temp = [14.2, 16.4, 11.9, 15.2, 18.5, 22.1, 19.4, 25.1, 23.4, 18.1, 22.6, 17.2]
sales = [215, 325, 185, 332, 406, 522, 412, 614, 544, 421, 445, 408]
scoop_price = [89, 18, 10, 28, 79, 46, 29, 38, 89, 26, 45, 62]

# %%
for i in arange(0,len(temp)):
    plt.annotate(scoop_price[1],(temp[i]-10,sales[i]+10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_925564\3120073316.py in <module>
# ----> 1 for i in arange(0,len(temp)):
#       2     plt.annotate(scoop_price[1],(temp[i]-10,sales[i]+10))
#
# NameError: name 'arange' is not defined

# %%
# Tell matplotlib to create a scatter plot based upon the above data
plt.scatter(temp, sales,facecolor="coral",edgecolor="lightskyblue",s=scoop_price)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Set the upper and lower limits of our y axis
plt.ylim(100,650)
# Out:
# (100.0, 650.0)

# %%
# Set the upper and lower limits of our x axis
plt.xlim(10,26)
# Out:
# (10.0, 26.0)

# %%
# Create a title, x label, and y label for our chart
plt.title("Ice Cream Sales vs Temperature")
plt.xlabel("Temperature (Celsius)")
plt.ylabel("Sales (USD)")
# Out:
# Text(38.097222222222214, 0.5, 'Sales (USD)')

# %%
# Save an image of the chart and print to screen
# NOTE: If your plot shrinks after saving an image,
# update matplotlib to 2.2 or higher,
# or simply run the above cells again.
