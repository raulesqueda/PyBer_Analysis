# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(bars_in_cities))

# %%
# Create a bar chart based upon the above data
plt.bar(x_axis, bars_in_cities)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 5 artists>

# %%
# Create the ticks for our bar chart's x axis
ticks_locations = [values for values in x_axis]
plt.xticks(ticks_locations, cities)
# Out:
# ([<matplotlib.axis.XTick at 0x1f0204ec508>,
#   <matplotlib.axis.XTick at 0x1f0204da2c8>,
#   <matplotlib.axis.XTick at 0x1f0204ec0c8>,
#   <matplotlib.axis.XTick at 0x1f020799708>,
#   <matplotlib.axis.XTick at 0x1f02079e548>],
#  [Text(0, 0, 'New Orleans'),
#   Text(1, 0, 'Milwaukee'),
#   Text(2, 0, 'Omaha'),
#   Text(3, 0, 'Pittsburgh'),
#   Text(4, 0, 'Toledo')])

# %%
# Set the limits of the x axis
plt.xlim(-0.75,len(x_axis)-0.25)
# Out:
# (-0.75, 4.75)

# %%
# Set the limits of the y axis
plt.ylim(0,max(bars_in_cities)+1)
# Out:
# (0.0, 9.6)

# %%
# Give the chart a title, x label, and y label
plt.ylabel("Bars per 10,000 Households")
plt.xlabel("City")
plt.title("Density of Bars in Major US Cities")
# Out:
# Text(0.5, 1.0, 'Density of Bars in Major US Cities')

# %%
# Save an image of the chart and print it to the screen
plt.savefig("BarDensity.png")
